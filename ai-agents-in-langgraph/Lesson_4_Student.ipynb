# %% [markdown]
# # Lesson 4: Persistence and Streaming

# %%
from dotenv import load_dotenv

_ = load_dotenv()

# %%
from langgraph.graph import StateGraph, END
from typing import TypedDict, Annotated
import operator
from langchain_core.messages import AnyMessage, SystemMessage, HumanMessage, ToolMessage
from langchain_openai import ChatOpenAI
from langchain_community.tools.tavily_search import TavilySearchResults

# %%
tool = TavilySearchResults(max_results=2)

# %%
class AgentState(TypedDict):
    messages: Annotated[list[AnyMessage], operator.add]

# %%
from langgraph.checkpoint.sqlite import SqliteSaver

memory = SqliteSaver.from_conn_string(":memory:")

# %%
class Agent:
    def __init__(self, model, tools, checkpointer, system=""):
        self.system = system
        graph = StateGraph(AgentState)
        graph.add_node("llm", self.call_openai)
        graph.add_node("action", self.take_action)
        graph.add_conditional_edges("llm", self.exists_action, {True: "action", False: END})
        graph.add_edge("action", "llm")
        graph.set_entry_point("llm")
        self.graph = graph.compile(checkpointer=checkpointer)
        self.tools = {t.name: t for t in tools}
        self.model = model.bind_tools(tools)

    def call_openai(self, state: AgentState):
        messages = state['messages']
        if self.system:
            messages = [SystemMessage(content=self.system)] + messages
        message = self.model.invoke(messages)
        return {'messages': [message]}

    def exists_action(self, state: AgentState):
        result = state['messages'][-1]
        return len(result.tool_calls) > 0

    def take_action(self, state: AgentState):
        tool_calls = state['messages'][-1].tool_calls
        results = []
        for t in tool_calls:
            print(f"Calling: {t}")
            result = self.tools[t['name']].invoke(t['args'])
            results.append(ToolMessage(tool_call_id=t['id'], name=t['name'], content=str(result)))
        print("Back to the model!")
        return {'messages': results}

# %%
prompt = """You are a smart research assistant. Use the search engine to look up information. \
You are allowed to make multiple calls (either together or in sequence). \
Only look up information when you are sure of what you want. \
If you need to look up some information before asking a follow up question, you are allowed to do that!
"""
model = ChatOpenAI(model="gpt-4o")
abot = Agent(model, [tool], system=prompt, checkpointer=memory)

# %%
messages = [HumanMessage(content="What is the weather in sf?")]

# %%
thread = {"configurable": {"thread_id": "1"}}

# %%
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v['messages'])
# Out:
# [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_bmfLa92f6oAIKN9KvXtqbKDz', 'function': {'arguments': '{"query":"current weather in San Francisco"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 151, 'total_tokens': 173, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_831e067d82', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-4d72ec9a-667c-4e0a-a606-3fa6978122e6-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in San Francisco'}, 'id': 'call_bmfLa92f6oAIKN9KvXtqbKDz'}])]
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in San Francisco'}, 'id': 'call_bmfLa92f6oAIKN9KvXtqbKDz'}
# Back to the model!
# [ToolMessage(content='[{\'url\': \'https://www.accuweather.com/en/us/san-francisco/94103/may-weather/347629\', \'content\': \'### Winter Center\\n\\n## Monthly\\n\\n## May\\n\\n## 2026\\n\\n## 10-Day\\n\\nCooler with clearing\\nAreas of low clouds, then sun\\nBreezy in the afternoon\\nBreezy in the afternoon\\nBreezy in the afternoon\\nBreezy in the afternoon\\nAreas of low clouds, then sun\\nAreas of low clouds, then sun\\nSunny\\nMostly sunny\\nA little morning rain; cloudy\\nPartly sunny\\nPartly sunny\\nA blend of sun and clouds\\nPlenty of sun\\nPlenty of sun\\nClouds and sun\\nMostly cloudy\\nPartly sunny\\nPlenty of sunshine\\nSunny\\nPartly sunny\\nMostly cloudy\\nMostly sunny\\nA blend of sun and clouds\\nCloudy\\n\\n## Temperature Graph\\n\\n## May Weather in San Francisco\\n\\n## Further Ahead\\n\\nFurther Ahead\\n\\n### June 2026\\n\\n### July 2026\\n\\n### August 2026\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Severe Weather\\n\\n### Radar & Maps\\n\\n### News\\n\\n### Video [...] # San Francisco, CA\\n\\nSan Francisco\\n\\nCalifornia\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Severe Weather\\n\\n### Radar & Maps\\n\\n### News & Features\\n\\n### Astronomy\\n\\n### Business\\n\\n### Climate\\n\\n### Health\\n\\n### Recreation\\n\\n### Sports\\n\\n### Travel\\n\\n### Warnings\\n\\n### Data Suite\\n\\n### Forensics\\n\\n### Advertising\\n\\n### Superior Accuracy™\\n\\n### Video\\n\\n### Winter Center\\n\\n## Monthly\\n\\n## May\\n\\n## 2026\\n\\n## 10-Day [...] ### Severe Weather\\n\\n### Radar & Maps\\n\\n### News\\n\\n### Video\\n\\n### Winter Center\\n\\nTop Stories\\n\\nWeather News\\n\\n10 rescued after small plane crashes off South Florida\\n\\n4 hours ago\\n\\nSevere Weather\\n\\nStorms to bring lightning, strong wind gusts from East to Rockies\\n\\n6 hours ago\\n\\nWeather Forecasts\\n\\nSudden summer weather on the way for Midwest, East next week\\n\\n8 hours ago\\n\\nRecreation\\n\\nEverest’s brief spring weather window brings a rush to the summit\\n\\n11 hours ago\\n\\nWeather Forecasts\\n\\nMid-May chill dominates the Northeast as wet weather moves in\\n\\n8 hours ago\\n\\nFeatured Stories\\n\\nRecreation\\n\\n1st fatal bear attack since 1998 reported in Glacier National Park\\n\\n1 day ago\\n\\nSevere Weather\\n\\nWhy sheltering under an overpass during severe weather is dangerous\\n\\n11 hours ago\\n\\nAstronomy\'}, {\'url\': \'https://www.accuweather.com/en/us/san-francisco/94103/weather-forecast/347629\', \'content\': "# San Francisco, CA\\n\\nSan Francisco\\n\\nCalifornia\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Severe Weather\\n\\n### Radar & Maps\\n\\n### News & Features\\n\\n### Astronomy\\n\\n### Business\\n\\n### Climate\\n\\n### Health\\n\\n### Recreation\\n\\n### Sports\\n\\n### Travel\\n\\n### Warnings\\n\\n### Data Suite\\n\\n### Forensics\\n\\n### Advertising\\n\\n### Superior Accuracy™\\n\\n### Video\\n\\n### Winter Center\\n\\n## Today\\n\\n## Tonight\'s Weather\\n\\nTue, May 12\\n\\nMainly clear early, then areas of low clouds forming with a passing shower\\nLo: 54°\\n\\nTomorrow: Areas of low clouds early; otherwise, mostly sunny\\nHi: 66°\\n\\n## Current Weather\\n\\n7:42 PM\\n\\n## San Francisco Weather Radar\\n\\nSan Francisco Weather Radar\\n\\n## Hourly Weather\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop [...] rain drop\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\n## 10-Day Weather Forecast\\n\\nTonight\\n\\n5/12\\n\\nPartly cloudy with a shower\\n\\nWed\\n\\n5/13\\n\\nAreas of low clouds, then sun\\n\\nNight: Areas of low clouds\\n\\nThu\\n\\n5/14\\n\\nBreezy in the afternoon\\n\\nPartly cloudy\\n\\nFri\\n\\n5/15\\n\\nBreezy in the afternoon\\n\\nPartly cloudy\\n\\nSat\\n\\n5/16\\n\\nBreezy in the afternoon ...
# [AIMessage(content='The current weather in San Francisco is mainly clear early, with areas of low clouds forming and a possibility of a passing shower. The temperature is around 54°F tonight. Tomorrow, there will be areas of low clouds early, but it will be mostly sunny with a high of 66°F.', response_metadata={'token_usage': {'completion_tokens': 60, 'prompt_tokens': 1534, 'total_tokens': 1594, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_8aed6409fd', 'finish_reason': 'stop', 'logprobs': None}, id='run-ec1684b9-a514-4607-9f8d-dced7733f27b-0')]

# %%
messages = [HumanMessage(content="What about in la?")]
thread = {"configurable": {"thread_id": "1"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
# Out:
# {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_bd1wAI6mLSFTZdkyXFpK8NcO', 'function': {'arguments': '{"query":"current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 1606, 'total_tokens': 1628, 'prompt_tokens_details': {'cached_tokens': 1536, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_8aed6409fd', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-cffb0c09-7443-4890-abf2-6beef749ffb6-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_bd1wAI6mLSFTZdkyXFpK8NcO'}])]}
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_bd1wAI6mLSFTZdkyXFpK8NcO'}
# Back to the model!
# {'messages': [ToolMessage(content='[{\'url\': \'https://www.accuweather.com/en/us/los-angeles/90012/may-weather/347625\', \'content\': \'### Winter Center\\n\\n## Monthly\\n\\n## May\\n\\n## 2026\\n\\n## 10-Day\\n\\nShowers late this morning\\nAreas of low clouds, then sun\\nAreas of low clouds, then sun\\nMostly sunny\\nSunshine and nice\\nMostly sunny and nice\\nPartly sunny and beautiful\\nAreas of low clouds, then sun\\nPartly sunny\\nPlenty of sunshine\\nSunny to partly cloudy\\nMostly sunny\\nMostly sunny\\nMostly sunny\\nPartial sunshine\\nTurning out cloudy\\nSunny\\nTurning cloudy\\nMostly sunny\\nPlenty of sunshine\\nMostly sunny\\nMostly cloudy\\nPlenty of sunshine\\nSunshine\\nMostly sunny\\nClouds rolling in\\n\\n## Temperature Graph\\n\\n## May Weather in Los Angeles\\n\\n## Further Ahead\\n\\nFurther Ahead\\n\\n### June 2026\\n\\n### July 2026\\n\\n### August 2026\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Severe Weather\\n\\n### Radar & Maps\\n\\n### News\\n\\n### Video\\n\\n### Winter Center [...] # Los Angeles, CA\\n\\nLos Angeles\\n\\nCalifornia\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Severe Weather\\n\\n### Radar & Maps\\n\\n### News & Features\\n\\n### Astronomy\\n\\n### Business\\n\\n### Climate\\n\\n### Health\\n\\n### Recreation\\n\\n### Sports\\n\\n### Travel\\n\\n### Warnings\\n\\n### Data Suite\\n\\n### Forensics\\n\\n### Advertising\\n\\n### Superior Accuracy™\\n\\n### Video\\n\\n### Winter Center\\n\\n## Monthly\\n\\n## May\\n\\n## 2026\\n\\n## 10-Day [...] ### Radar & Maps\\n\\n### News\\n\\n### Video\\n\\n### Winter Center\\n\\nTop Stories\\n\\nWeather News\\n\\n10 rescued after small plane crashes off South Florida\\n\\n4 hours ago\\n\\nSevere Weather\\n\\nStorms to bring lightning, strong wind gusts from East to Rockies\\n\\n6 hours ago\\n\\nWeather Forecasts\\n\\nSudden summer weather on the way for Midwest, East next week\\n\\n8 hours ago\\n\\nRecreation\\n\\nEverest’s brief spring weather window brings a rush to the summit\\n\\n11 hours ago\\n\\nWeather Forecasts\\n\\nMid-May chill dominates the Northeast as wet weather moves in\\n\\n8 hours ago\\n\\nFeatured Stories\\n\\nRecreation\\n\\n1st fatal bear attack since 1998 reported in Glacier National Park\\n\\n1 day ago\\n\\nSevere Weather\\n\\nWhy sheltering under an overpass during severe weather is dangerous\\n\\n11 hours ago\\n\\nAstronomy\'}, {\'url\': \'https://weather.com/weather/today/l/USC+Los+Angeles+California?canonicalCityId=7d3c65d8b80674fb48647ddbc936bb8b\', \'content\': "Data Vendors\\n\\nAdChoices\\n\\nAccessibility Statement\\n\\nCommunity Guidelines\\n\\nMore\\n\\nMission\\n\\nNewsletter Sign Up\\n\\nFeedback\\n\\nCareers\\n\\nNews Room\\n\\nAdvertise With Us\\n\\nTV\\n\\nWeather Data APIs\\n\\nAlexa Skill\\n\\nWeather Labs\\n\\nAtmosphere\\n\\n© The Weather Company, LLC 2026\\n\\nExplore Georgia\\nEssential Accessibility [...] Home\\n\\nHome\\n\\nForecast\\n\\nForecast\\n\\nRadar\\n\\nRadar\\n\\nVideo\\n\\nVideo\\n\\nExplore\\n\\nExplore\\n\\n## Los Angeles Weather\\n\\nUSC, Los Angeles, California\\n\\n## Today\'s Outlook\\n\\n## Things to do around Los Angeles\\n\\n# Daily Forecast\\n\\n## Trending Now\\n\\n## Rain Can\'t Come Soon Enough; Drone Footage Captures Fast-Moving Flames In Florida\\n\\n0:18\\n\\n## Damaging Winds, Tornadoes Possible For Storm-Fatigued Areas\\n\\n## This Divisive Scent Could Save You From Mosquito Bites\\n\\n0:31\\n\\n## Why Western Wildfires Are Burning Longer, Spreading Faster\\n\\n0:40\\n\\n## Rain Can\'t Come Soon Enough; Drone Footage Captures Fast-Moving Flames In Florida\\n\\n0:18\\n\\n## Damaging Winds, Tornadoes Possible For Storm-Fatigued Areas\\n\\n## This Divisive Scent Could Save You From Mosquito Bites\\n\\n0:31\\n\\n## Why Western Wildfires Are Burning Longer, Spreading Faster [...] 0:40\\n\\n## Home & Garden\\n\\n## Home Insurance Weather Disasters You’re Not Prepared For\\n\\n0:43\\n\\n## The Sprin ...
# {'messages': [AIMessage(content='The current weather in Los Angeles includes some showers expected late in the morning, followed by areas of low clouds clearing to sunshine. The overall forecast suggests mostly sunny and nice conditions.', response_metadata={'token_usage': {'completion_tokens': 36, 'prompt_tokens': 2763, 'total_tokens': 2799, 'prompt_tokens_details': {'cached_tokens': 1536, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_8aed6409fd', 'finish_reason': 'stop', 'logprobs': None}, id='run-4200acb7-22c6-4c12-b2c4-5c6f624a61a7-0')]}

# %%
messages = [HumanMessage(content="Which one is warmer?")]
thread = {"configurable": {"thread_id": "1"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
# Out:
# {'messages': [AIMessage(content='Based on the current forecasts, Los Angeles is warmer than San Francisco. Los Angeles is expecting a generally sunny and nice day, while San Francisco is experiencing cooler temperatures with a high of 66°F and areas of low clouds early in the day.', response_metadata={'token_usage': {'completion_tokens': 50, 'prompt_tokens': 2811, 'total_tokens': 2861, 'prompt_tokens_details': {'cached_tokens': 2688, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_8aed6409fd', 'finish_reason': 'stop', 'logprobs': None}, id='run-4e8cb6f4-ba48-4595-a62d-1a126d22ccb1-0')]}

# %%
messages = [HumanMessage(content="Which one is warmer?")]
thread = {"configurable": {"thread_id": "2"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
# Out:
# {'messages': [AIMessage(content="Could you please clarify what you're comparing to determine which is warmer? Are you comparing two specific locations, types of clothing, materials, or something else? Let me know so I can provide the appropriate information.", response_metadata={'token_usage': {'completion_tokens': 43, 'prompt_tokens': 149, 'total_tokens': 192, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_f9f4fb6dbf', 'finish_reason': 'stop', 'logprobs': None}, id='run-211d8bee-39f0-4679-87fc-c706d4f4e787-0')]}

# %% [markdown]
# ## Streaming tokens

# %%
from langgraph.checkpoint.aiosqlite import AsyncSqliteSaver

memory = AsyncSqliteSaver.from_conn_string(":memory:")
abot = Agent(model, [tool], system=prompt, checkpointer=memory)

# %%
messages = [HumanMessage(content="What is the exact weather in SF?")]
thread = {"configurable": {"thread_id": "4"}}
async for event in abot.graph.astream_events({"messages": messages}, thread, version="v1"):
    kind = event["event"]
    if kind == "on_chat_model_stream":
        content = event["data"]["chunk"].content
        if content:
            # Empty content in the context of OpenAI means
            # that the model is asking for a tool to be invoked.
            # So we only print non-empty content
            print(content, end="|")
# Out:
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in San Francisco'}, 'id': 'call_aKis5tk1870sbC8O8Jd25MD9'}
# Back to the model!
# The| current| weather| in| San| Francisco| is| mostly| cloudy|.| If| you| need| more| detailed| or| updated| information|,| I| recommend| checking| a| reliable| weather| website| or| app| like| Weather| Underground| or| Acc|u|Weather|.|
